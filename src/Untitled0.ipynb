# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Jx9LQDHoCVXSnAjG1WxK")
project = rf.workspace("m-ali-lafy2021-gmail-com").project("my-first-project-8pm8f-q5hni")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics
from ultralytics import YOLO
model = YOLO("yolo26n-obb.pt")
results = model.train(data=f"{dataset.location}/data.yaml", epochs=100, imgsz=320, device=0)
